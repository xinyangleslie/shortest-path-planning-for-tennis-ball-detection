# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Jj3Ie46ahQdWtW5viBdt")
project = rf.workspace("tennis-3ll0a").project("tennis-ball-icifx")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 106.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to tennis-ball-1 in yolov11:: 100%|██████████| 716/716 [00:00<00:00, 9633.76it/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Jj3Ie46ahQdWtW5viBdt")
project = rf.workspace("max-bousquet").project("tennisball3")
version = project.version(11)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to TennisBall3-11 in yolov11:: 100%|██████████| 2546/2546 [00:00<00:00, 2873.72it/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Jj3Ie46ahQdWtW5viBdt")
project = rf.workspace("uc-berkely-w210-tracer").project("tracer-tennis-ball")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Tracer---tennis-ball--1 in yolov11:: 100%|██████████| 2204/2204 [00:00<00:00, 8727.95it/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Jj3Ie46ahQdWtW5viBdt")
project = rf.workspace("yong-project").project("jjeong")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to JJEONG-2 in yolov11:: 100%|██████████| 360/360 [00:00<00:00, 10760.68it/s]

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Jj3Ie46ahQdWtW5viBdt")
project = rf.workspace("max-bousquet").project("tennisball3")
version = project.version(11)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %%
import shutil
import os

datasets = ["JJEONG-2", "TennisBall3-11","Tracer---tennis-ball--1", "tennis-ball-1"]
splits = ["train", "valid", "test"]

output = "merged_dataset"

for split in splits:
    os.makedirs(f"{output}/{split}/images", exist_ok=True)
    os.makedirs(f"{output}/{split}/labels", exist_ok=True)

for dataset in datasets:
    for split in splits:

        img_src = f"{dataset}/{split}/images"
        lbl_src = f"{dataset}/{split}/labels"

        img_dst = f"{output}/{split}/images"
        lbl_dst = f"{output}/{split}/labels"

        for file in os.listdir(img_src):
            shutil.copy(os.path.join(img_src, file), img_dst)

        for file in os.listdir(lbl_src):
            shutil.copy(os.path.join(lbl_src, file), lbl_dst)

# %%
import os

label_folders = [
    "merged_dataset/train/labels",
    "merged_dataset/valid/labels",
    "merged_dataset/test/labels"
]

for folder in label_folders:
    for file in os.listdir(folder):
        path = os.path.join(folder, file)

        with open(path, "r") as f:
            lines = f.readlines()

        new_lines = []
        for line in lines:
            parts = line.split()
            parts[0] = "0"   # force class id to 0
            new_lines.append(" ".join(parts))

        with open(path, "w") as f:
            f.write("\n".join(new_lines))

# %%
from google.colab import files

folder_to_download = "TennisBall_Detection"
archive_name = f"{folder_to_download}.zip"

# Create a zip archive of the folder
shutil.make_archive(folder_to_download, 'zip', folder_to_download)

# Download the created zip file
files.download(archive_name)
